# %%
import pandas as pd

# %%
customer = pd.read_csv('Customer_Feedback_Data.csv')
product = pd.read_csv('Product_Offering_Data.csv')
transaction = pd.read_csv('Transaction_Data.csv')

# %%
customer
# Out:
#       Customer_ID  Satisfaction_Score  Feedback_Comments  \
# 0               1                10.0     Very satisfied
# 1               2                 3.0     Very satisfied
# 2               3                10.0     Very satisfied
# 3               4                 7.0  Needs improvement
# 4               5                 8.0     Unsatisfactory
# ...           ...                 ...                ...
# 5045          757                 9.0       Good service
# 5046          969                 2.0     Unsatisfactory
# 5047          248                 4.0       Good service
# 5048           58                 4.0     Unsatisfactory
# 5049          635                 4.0     Very satisfied
#
#       Likelihood_to_Recommend
# 0                           9
# 1                           3
# 2                           1
# 3                           4
# 4                           7
# ...                       ...
# 5045                        3
# ...

# %%
product
# Out:
#     Product_ID                   Product_Name     Product_Type Risk_Level  \
# 0            1           Platinum Credit Card      Credit Card     Medium
# 1            2           Gold Savings Account  Savings Account        Low
# 2            3  High-Yield Investment Account       Investment       High
# 3            4                  Mortgage Loan             Loan     Medium
# 4            5                      Auto Loan             Loan     Medium
# 5            6                  Personal Loan             Loan     Medium
# 6            7          Youth Savings Account  Savings Account        Low
# 7            8     Retirement Investment Fund       Investment       High
# 8            9                  Business Loan             Loan     Medium
# 9           10             Travel Credit Card      Credit Card     Medium
# 10           2           Gold Savings Account  Savings Account        Low
# 11          10             Travel Credit Card      Credit Card     Medium
# ...

# %%
transaction
# Out:
#       Transaction_ID  Customer_ID     Transaction_Date  Transaction_Amount  \
# 0                  1          393  2023-01-01 00:00:00              3472.0
# 1                  2          826  2023-01-01 01:00:00                 NaN
# 2                  3          916  2023-01-01 02:00:00                10.0
# 3                  4          109  2023-01-01 03:00:00                72.0
# 4                  5          889  2023-01-01 04:00:00              1793.0
# ...              ...          ...                  ...                 ...
# 5045            3034          317  2023-05-07 09:00:00              3018.0
# 5046             583          336  2023-01-25 06:00:00              2670.0
# 5047            1211          550  2023-02-20 10:00:00              3252.0
# 5048            2259          258  2023-04-05 02:00:00              3442.0
# 5049            1159          271  2023-02-18 06:00:00               108.0
#
#      Transaction_Type
# 0            Purchase
# ...

# %%
customer.isnull().sum()
# Out:
# Customer_ID                  0
# Satisfaction_Score         101
# Feedback_Comments            0
# Likelihood_to_Recommend      0
# dtype: int64

# %%
product.isnull().sum()
# Out:
# Product_ID              0
# Product_Name            0
# Product_Type            0
# Risk_Level              0
# Target_Age_Group       15
# Target_Income_Group     0
# dtype: int64

# %%
transaction.isnull().sum()
# Out:
# Transaction_ID          0
# Customer_ID             0
# Transaction_Date        0
# Transaction_Amount    100
# Transaction_Type        0
# dtype: int64

# %%
customer['Satisfaction_Score'] = customer['Satisfaction_Score'].fillna(value=customer['Satisfaction_Score'].mode())

# %%
transaction['Transaction_Amount'] = transaction['Transaction_Amount'].fillna(value=transaction['Transaction_Amount'].mean())

# %%
customer
# Out:
#       Customer_ID  Satisfaction_Score  Feedback_Comments  \
# 0               1                10.0     Very satisfied
# 1               2                 3.0     Very satisfied
# 2               3                10.0     Very satisfied
# 3               4                 7.0  Needs improvement
# 4               5                 8.0     Unsatisfactory
# ...           ...                 ...                ...
# 5045          757                 9.0       Good service
# 5046          969                 2.0     Unsatisfactory
# 5047          248                 4.0       Good service
# 5048           58                 4.0     Unsatisfactory
# 5049          635                 4.0     Very satisfied
#
#       Likelihood_to_Recommend
# 0                           9
# 1                           3
# 2                           1
# 3                           4
# 4                           7
# ...                       ...
# 5045                        3
# ...

# %%
transaction
# Out:
#       Transaction_ID  Customer_ID     Transaction_Date  Transaction_Amount  \
# 0                  1          393  2023-01-01 00:00:00         3472.000000
# 1                  2          826  2023-01-01 01:00:00         3094.726465
# 2                  3          916  2023-01-01 02:00:00           10.000000
# 3                  4          109  2023-01-01 03:00:00           72.000000
# 4                  5          889  2023-01-01 04:00:00         1793.000000
# ...              ...          ...                  ...                 ...
# 5045            3034          317  2023-05-07 09:00:00         3018.000000
# 5046             583          336  2023-01-25 06:00:00         2670.000000
# 5047            1211          550  2023-02-20 10:00:00         3252.000000
# 5048            2259          258  2023-04-05 02:00:00         3442.000000
# 5049            1159          271  2023-02-18 06:00:00          108.000000
#
#      Transaction_Type
# 0            Purchase
# ...

# %%
product = product.drop_duplicates(subset=['Product_ID'], keep='first')

# %%
product
# Out:
#    Product_ID                   Product_Name     Product_Type Risk_Level  \
# 0           1           Platinum Credit Card      Credit Card     Medium
# 1           2           Gold Savings Account  Savings Account        Low
# 2           3  High-Yield Investment Account       Investment       High
# 3           4                  Mortgage Loan             Loan     Medium
# 4           5                      Auto Loan             Loan     Medium
# 5           6                  Personal Loan             Loan     Medium
# 6           7          Youth Savings Account  Savings Account        Low
# 7           8     Retirement Investment Fund       Investment       High
# 8           9                  Business Loan             Loan     Medium
# 9          10             Travel Credit Card      Credit Card     Medium
#
#    Target_Age_Group Target_Income_Group
# 0               NaN              Medium
# 1               NaN                 Low
# 2               NaN                High
# ...

# %%
type(transaction.Transaction_Date[0])
# Out:
# str

# %%
transaction['Transaction_Date'] = pd.to_datetime(transaction['Transaction_Date'])

# %%
transaction
# Out:
#       Transaction_ID  Customer_ID    Transaction_Date  Transaction_Amount  \
# 0                  1          393 2023-01-01 00:00:00         3472.000000
# 1                  2          826 2023-01-01 01:00:00         3094.726465
# 2                  3          916 2023-01-01 02:00:00           10.000000
# 3                  4          109 2023-01-01 03:00:00           72.000000
# 4                  5          889 2023-01-01 04:00:00         1793.000000
# ...              ...          ...                 ...                 ...
# 5045            3034          317 2023-05-07 09:00:00         3018.000000
# 5046             583          336 2023-01-25 06:00:00         2670.000000
# 5047            1211          550 2023-02-20 10:00:00         3252.000000
# 5048            2259          258 2023-04-05 02:00:00         3442.000000
# 5049            1159          271 2023-02-18 06:00:00          108.000000
#
#      Transaction_Type
# 0            Purchase
# 1        Bill Payment
# ...
